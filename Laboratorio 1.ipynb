# %% [markdown]
# # Laboratorio 1

# %% [markdown]
# ## Librerias importadas

# %%
#imports del ambiente virtual
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('Admission_Predict.csv')

# %% [markdown]
# ## Se comienza definiendo los datos a utilizar (los mas relevantes)

# %%
print(data)
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
TOEFL = data.iloc[:, 2].values
UR = data.iloc[:, 3].values
CGPA = data.iloc[:, 6].values
R = data.iloc[:, 7].values
CoA = data.iloc[:, 8].values

# %%
plt.plot(TOEFL, CoA, 'bo')

# %%
plt.plot(CGPA, CoA, 'bo')

# %%
plt.scatter(CGPA, CoA)

# %%
CGPA = data.iloc[:, 6].values
CoA = data.iloc[:, 8].values
x = CGPA
y = CoA
b, m = np.polyfit(x, y, 1)
plt.plot(x, y, '.')
plt.plot(x, b + (m * x), '-')
plt.show()

# %%
CGPA = data.iloc[:, 6].values.reshape(-1, 1)
CoA = data.iloc[:, 8].values.reshape(-1, 1)
x = CGPA
y = CoA
linear_regressor = LinearRegression()
linear_regressor.fit(x,y)
y_pred = linear_regressor.predict(x)
plt.scatter(x, y)
plt.plot(x, y_pred, color='red')
plt.show()

# %% [markdown]
# Se hizo una prueba previa con unas funciones para determinar la regresion lineal entre CoA y el CGPA, la razon de esto era comprobar si tenian alguna relacion un mayor puntaje escolar o GPA con la oportunidad de ser aceptado.
# Luego se decidio que se haria una comparación entre el GPA y el TOEFL para verificar si el conocimiento escolar con el nivel de ingles tenían alguna relación y ver si se podía crear una nueva variable "mezclando" ambas y poder compararlas con la oportunidad de ser aceptados y ver si aumenta la correlación de las variables.

# %%
TOEFL = data.iloc[:, 2].values.reshape(-1, 1)
CoA = data.iloc[:, 8].values.reshape(-1, 1)
x = TOEFL
y = CoA
linear_regressor = LinearRegression()
linear_regressor.fit(x,y)
y_pred = linear_regressor.predict(x)
plt.scatter(x, y)
plt.plot(x, y_pred, color='red')
plt.show()

# %%
TOEFL = data.iloc[:, 2].values.reshape(-1, 1)
CGPA = data.iloc[:, 6].values.reshape(-1, 1)
x = CGPA
y = TOEFL
linear_regressor = LinearRegression()
linear_regressor.fit(x,y)
y_pred = linear_regressor.predict(x)
plt.scatter(x, y)
plt.plot(x, y_pred, color='red')
plt.show()

# %%
TOEFL = data.iloc[:, 2].values.reshape(-1, 1)
CGPA = data.iloc[:, 6].values.reshape(-1, 1)
CoA = data.iloc[:, 8].values.reshape(-1, 1)
x = CGPA * TOEFL
y = CoA
linear_regressor = LinearRegression()
linear_regressor.fit(x,y)
y_pred = linear_regressor.predict(x)
plt.scatter(x, y)
plt.plot(x, y_pred, color='red')
plt.show()

# %% [markdown]
# En este momento se decidió no tomar las variables individuales para compararlas con la probabilidad de aceptación, sino que se decidió tomarlas por parejas relevantes y de acuerdo a mi conocimiento en ingreso de universidades en USA juega un papel más importante el GPA que el TOEFL pero igual siempre piden un nivel mínimo del habla del idioma. La multiplicación de los valores se acerca más a un modelo donde es más predecible que la suma de ellos ya que el TOEFL es sobre 120 puntos mientras que la del GPA es sobre 10, asi que pareciera que el TOEFL tiene más importancia aunque no es la realidad, es por ello que se decidió que el GPA fuera un factor multiplicativo para que tuviera un mayor peso el GPA al resultado.

# %%
TOEFL = data.iloc[:, 2].values.reshape(-1, 1)
CGPA = data.iloc[:, 6].values.reshape(-1, 1)
CoA = data.iloc[:, 8].values.reshape(-1, 1)
x = CGPA + TOEFL
y = CoA
linear_regressor = LinearRegression()
linear_regressor.fit(x,y)
y_pred = linear_regressor.predict(x)
plt.scatter(x, y)
plt.plot(x, y_pred, color='red')
plt.show()

# %%
TOEFL = data.iloc[:, 2].values.reshape(-1, 1)
UR = data.iloc[:, 3].values.reshape(-1, 1)
CGPA = data.iloc[:, 6].values.reshape(-1, 1)
CoA = data.iloc[:, 8].values.reshape(-1, 1)
x = (CGPA * TOEFL) / UR
y = CoA
linear_regressor = LinearRegression()
linear_regressor.fit(x,y)
y_pred = linear_regressor.predict(x)
plt.scatter(x, y)
plt.plot(x, y_pred, color='red')
plt.show()

# %%
TOEFL = data.iloc[:, 2].values.reshape(-1, 1)
UR = data.iloc[:, 3].values.reshape(-1, 1)
CGPA = data.iloc[:, 6].values.reshape(-1, 1)
R = data.iloc[:, 7].values.reshape(-1, 1)
CoA = data.iloc[:, 8].values.reshape(-1, 1)
x = (CGPA * TOEFL) / UR
y = CoA
linear_regressor = LinearRegression()
linear_regressor.fit(x,y)
y_pred = linear_regressor.predict(x)
plt.scatter(x, y)
plt.plot(x, y_pred, color='red')
plt.show()

# %%
UR = data.iloc[:, 3].values.reshape(-1, 1)
R = data.iloc[:, 7].values.reshape(-1, 1)
CoA = data.iloc[:, 8].values.reshape(-1, 1)
x = UR * R
y = CoA
linear_regressor = LinearRegression()
linear_regressor.fit(x,y)
y_pred = linear_regressor.predict(x)
plt.scatter(x, y)
plt.plot(x, y_pred, color='red')
plt.show()

# %% [markdown]
# En este punto se decidió tomar si el estudiante estaba en investigación o como estudiante de investigación (1) contra aquellos que no lo estaban (0) y luego se muestra la gráfica solo entre el rating de universidad contra la probabilidad de admisión y en efecto se puede ver que ser estudiante de investigación aumenta las probabilidades en algunos casos, ya que en la gráfica de arriba se observa que aunque hay muchos que no están en investigación y su rating de aceptación es muy variado, aquellos de investigación de rating 3 para arriba suelen ser los de las probabilidades más altas.

# %%
UR = data.iloc[:, 3].values.reshape(-1, 1)
R = data.iloc[:, 7].values.reshape(-1, 1)
CoA = data.iloc[:, 8].values.reshape(-1, 1)
x = UR
y = CoA
linear_regressor = LinearRegression()
linear_regressor.fit(x,y)
y_pred = linear_regressor.predict(x)
plt.scatter(x, y)
plt.plot(x, y_pred, color='red')
plt.show()

# %% [markdown]
# ## Comenzamos con los algoritmos de AI para no seguir solo trabajando con regresion lineal y hacer un mejor algoritmo de prediccion

# %%
CGPA = data.iloc[:, 6].values
largo = len(CGPA)
CGPAT = []
CGPATest = []
trainingSize = int(largo * 70/100)
testSize = int(largo * 30/100)
CGPA = CGPA.tolist()
for x in range(0, trainingSize):
    largo = len(CGPA)
    nodato = np.random.randint(0, largo)
    dato = CGPA[nodato]
    CGPA.remove(dato)
    CGPAT.append(dato)

for x in range(0, testSize):
    largo = len(CGPA)
    nodato = np.random.randint(0, largo)
    dato = CGPA[nodato]
    CGPA.remove(dato)
    CGPATest.append(dato)
